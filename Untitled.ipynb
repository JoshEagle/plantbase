# %%
import os
from tensorflow.keras.preprocessing.image import load_img
from PIL import Image

path = ('plantbase/data/plant_examples')

plant_name = 'Verbascum'
pl= Image.open(f'{path}/{plant_name}.jpg')
pl2= Image.open(f'{path}/{plant_name}{"2.jpg"}')
def flowers():
    for file in os.listdir(path):
        if plant_name in file:
            pl, pl2
        return pl, pl2
    #         plant.resize((224,224))
    #         plant2.resize((224,224))

# %%
pl
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x450 at 0x27F4C3C62C8>

# %%
pl2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1290x960 at 0x27F4C3BE048>

# %%
for file in os.listdir(path):
    pl2= Image.open(f'plantbase/data/plant_examples/{plant_name}{"2.jpg"}')

# %%
pl2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1290x960 at 0x27F4C3ACB88>

# %%
upper= ('plantbase/data/plant_examples')

# %%
plants_care = pd.read_csv('plantbase/scraping/plant_info_wk2.csv')
# Out:
# 'plantbase/data/plant_examples'

# %%
plant_name= plants_care['Genus name'].iloc[0]
