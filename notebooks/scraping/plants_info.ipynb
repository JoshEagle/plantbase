# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

import os
os.getcwd() #get working directory
# Out:
# 'C:\\Users\\User\\code\\Joshymitzu\\plantbase\\notebooks\\scraping'

# %%
root_path = os.getcwd()
csv_path = os.path.join(root_path,'data') #to run from folder on machine  path (root_path,'..','..','raw_data')
csv_path
# Out:
# 'C:\\Users\\User\\code\\Joshymitzu\\plantbase\\notebooks\\scraping\\data'

# %%
df= pd.read_csv(os.path.join(csv_path,'plants_info_enhanced.csv'))
df
# Out:
#               Family          Genus  Species  \
# 0      Agapanthaceae     Agapanthus      NaN
# 1         Asteraceae  Chrysanthemum      NaN
# 2     Amaryllidaceae      Daffodils      NaN
# 3         Onagraceae        Fuchsia      NaN
# 4       Asparagaceae       Hyacinth      NaN
# 5      Hydrangeaceae      Hydrangea      NaN
# 6          Iridaceae           Iris      NaN
# 7           Oleaceae        Jasmine      NaN
# 8          Lamiaceae       Lavender      NaN
# 9        Paeoniaceae          Peony      NaN
# 10         Ericaceae   Rhododendron      NaN
# 11        Rosaceae\n          Roses      NaN
# 12    Amaryllidaceae      Snowdrops      NaN
# 13         Liliaceae          Tulip      NaN
# 14          Fabaceae       Wisteria      NaN
# 15     Campanulaceae      Campanula      NaN
# 16  Scrophulariaceae      Verbascum      NaN
# 17          Rosaceae      Crataegus      NaN
# 18       Geraniaceae       Geranium      NaN
# 19       Orchidaceae         Ophrys      NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Family                                                         0
# Genus                                                          0
# Species                                                       20
# Genus description                                              0
# Genus details                                                  1
# Characteristics_Foliage                                        0
# Characteristics_Habit                                          0
# Characteristics _Hardiness                                     0
# Colour in autumn fruits                                       18
# Colour in autumn foliage                                       7
# Colour in autumn flowers                                      14
# Colour in spring foilage                                       3
# Colour in spring flower                                       10
# Colour in summer  foilage                                      7
# ...

# %%
# key_names = []
# for f in file_names:
#     if f == 'product_category_name_translation.csv':
#         key_names.append('product_category_name_translation')
#     else:
#         key_names.append(f[6:-12])
#         #key_names.append(f.replace('olist_', '').replace('dataset.csv', ''))
# key_names

# %%
# # Create the dictionary
# data = {}
# for k, f in zip(key_names, file_names):
#     data[k] = pd.read_csv(os.path.join(csv_path, f))

# data.keys()
