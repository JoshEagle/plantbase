# %% [markdown]
# ### Imports

# %%
from __future__ import print_function

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import tensorflow
import os 
from PIL import Image
import glob

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ### Loading the data

# %%
train_directory = r"../raw_data/train"

# %%
# creating the training dataset as a subset of our 'train' images folder
# labels are inferred from the subfolders

train_dataset = image_dataset_from_directory(
    train_directory, labels='inferred', label_mode='int',
    color_mode='rgb', batch_size=32, image_size=(256, 256), shuffle=True, seed=123,
    validation_split=0.2, subset="training", interpolation='bilinear', follow_links=False
)
# Out:
# Found 4317 files belonging to 16 classes.
# Using 3454 files for training.

# %%
# creating the validation dataset as a subset of our 'train' images folder
# labels are inferred from the subfolders

val_dataset = image_dataset_from_directory(
    train_directory, labels='inferred', label_mode='int',
    color_mode='rgb', batch_size=32, image_size=(256, 256), shuffle=True, seed=123,
    validation_split=0.2, subset="validation", interpolation='bilinear', follow_links=False
)
# Out:
# Found 4317 files belonging to 16 classes.
# Using 863 files for validation.

# %%
img_height, img_width = (256,256)

# %%
num_classes = 16

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(64, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4194368
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                1040
# =================================================================
# Total params: 4,218,992
# Trainable params: 4,218,992
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 1

history = model.fit(
  train_dataset,
  validation_data=val_dataset,
  epochs=epochs
)
# Out:
# 108/108 [==============================] - 84s 776ms/step - loss: 2.5631 - accuracy: 0.2070 - val_loss: 2.3675 - val_accuracy: 0.2908

# %% [markdown]
# ### Plotting learning curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Making predictions

# %%
test_df = pd.read_csv("../plantbase/data/test_data.csv").drop(columns = "Unnamed: 0")

# %%
test_df = test_df[['id', 'genus']]
test_df.head()
# Out:
#        id      genus
# 0  100035  Verbascum
# 1  100058  Trifolium
# 2  100186   Veronica
# 3  100238  Campanula
# 4    1003   Geranium

# %%
test_df.shape
# Out:
# (1341, 2)

# %%
test_df[test_df['id'] == 62]
# Out:
#      id      genus
# 844  62  Trifolium

# %%
columns = np.sort(test_df.genus.unique())
columns
# Out:
# array(['Ajuga', 'Allium', 'Campanula', 'Cirsium', 'Crataegus', 'Gentiana',
#        'Geranium', 'Iris', 'Malva', 'Narcissus', 'Ophrys', 'Rosa',
#        'Trifolium', 'Verbascum', 'Veronica', 'Viola'], dtype=object)

# %%
rename_columns = {}
col_index = 0
for n in columns:
    rename_columns[col_index] = n
    col_index += 1
    
rename_columns
# Out:
# {0: 'Ajuga',
#  1: 'Allium',
#  2: 'Campanula',
#  3: 'Cirsium',
#  4: 'Crataegus',
#  5: 'Gentiana',
#  6: 'Geranium',
#  7: 'Iris',
#  8: 'Malva',
#  9: 'Narcissus',
#  10: 'Ophrys',
#  11: 'Rosa',
#  12: 'Trifolium',
#  13: 'Verbascum',
#  14: 'Veronica',
#  15: 'Viola'}

# %% [markdown]
# #### loading test images using tensorflow load_img and img_to_array

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# %%
# %%time

X_list = []
y_list = []

for index, row in test_df.iterrows():
    img = load_img(rf"../raw_data/test/{row.id}.jpg", target_size=(256, 256))
    img = tensorflow.keras.preprocessing.image.img_to_array(img)
    #img = tensorflow.expand_dims(img, 0)
    X_list.append(img)
    y_list.append((row.genus, row.id))
# Out:
# Wall time: 6.82 s

# %%
test_df[test_df['id'] == 100238]
# Out:
#        id      genus
# 3  100238  Campanula

# %%
y_true_df = pd.DataFrame(y_list, columns = ['true_genus', 'id'])
y_true_df.head()
# Out:
#   true_genus      id
# 0  Verbascum  100035
# 1  Trifolium  100058
# 2   Veronica  100186
# 3  Campanula  100238
# 4   Geranium    1003

# %%
X_test = np.stack(X_list, axis=0)

# %%
# tst_img = tensorflow.keras.preprocessing.image.load_img(
#     rf"../raw_data/test/62.jpg", target_size=(256, 256))

# tst_img_array = tensorflow.keras.preprocessing.image.img_to_array(tst_img)
# tst_img_array = tensorflow.expand_dims(tst_img_array, 0)

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (1341, 16)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df = y_pred_df.rename(columns = rename_columns)
y_pred_df.head()
# Out:
#       Ajuga    Allium  Campanula   Cirsium  Crataegus  Gentiana  Geranium  \
# 0 -0.375045 -1.099686  -0.711595  0.473100  -1.171707  1.016644  0.122856
# 1  1.976996 -2.604533   0.189381 -2.215130  -2.773472  2.029676  0.528427
# 2  0.150083 -0.651813   0.673039  0.582385  -0.504183  0.727306  1.392239
# 3  0.416089 -0.901790   1.403908  0.517593  -0.540563  2.253790  0.440279
# 4  0.356223 -0.765871   1.017924  0.210691  -0.437511  0.784489  1.003653
#
#        Iris     Malva  Narcissus    Ophrys      Rosa  Trifolium  Verbascum  \
# 0  0.487261 -0.612631   0.452693  1.685862 -1.336651  -0.011222   1.489159
# 1  2.589401 -0.221971   0.905883 -1.673178 -1.438025  -2.276607  -0.319322
# 2 -0.345021 -0.074036  -1.064208  0.925776 -0.683254  -0.934431  -0.952826
# 3  0.955896  0.439329   0.088416  0.306997 -1.375822  -1.279450  -1.936976
# 4 -0.186409  0.282302  -1.088736  0.162990 -0.803298  -1.426403  -1.422720
#
#    Veronica     Viola
# 0 -2.978709 -1.338057
# 1  1.084313  1.045270
# 2  0.104517 -0.144562
# 3 -0.425926  0.387330
# 4  0.726319  0.201529

# %%
y_list
# Out:
# [('Verbascum', 100035),
#  ('Trifolium', 100058),
#  ('Veronica', 100186),
#  ('Campanula', 100238),
#  ('Geranium', 1003),
#  ('Ophrys', 100304),
#  ('Veronica', 10044),
#  ('Narcissus', 100448),
#  ('Ophrys', 10049),
#  ('Campanula', 100670),
#  ('Rosa', 100683),
#  ('Geranium', 100694),
#  ('Viola', 10092),
#  ('Allium', 100942),
#  ('Trifolium', 100971),
#  ('Ophrys', 101000),
#  ('Veronica', 101260),
#  ('Cirsium', 10130),
#  ('Ophrys', 101745),
#  ('Campanula', 101829),
#  ('Geranium', 101850),
#  ('Cirsium', 101884),
#  ('Campanula', 101969),
#  ('Campanula', 102018),
#  ('Crataegus', 10206),
#  ('Ophrys', 102082),
#  ('Verbascum', 102097),
#  ('Geranium', 102239),
#  ('Iris', 102252),
#  ('Veronica', 102364),
#  ('Ophrys', 102365),
#  ('Allium', 102550),
#  ('Trifolium', 102673),
#  ('Verbascum', 102684),
#  ('Ajuga', 102850),
#  ('Viola', 102881),
#  ('Cirsium', 102886),
#  ('Viola', 103007),
#  ('Ophrys', 103279),
#  ('Narcissus', 10335),
#  ('Verbascum', 103463),
#  ('Ophrys', 103479),
#  ('Ophrys', 103568),
#  ('Malva', 103570),
#  ('Trifolium', 103657),
#  ('Trifolium', 103736),
#  ('Geranium', 103779),
#  ('Viola', 103832),
#  ('Ophrys', 103916),
#  ('Cirsium', 103960),
#  ('Geranium', 104099),
#  ('Trifolium', 104112),
#  ('Rosa', 104114),
#  ('Iris', 104191),
#  ('Viola', 104267),
#  ('Rosa', 104271),
#  ('Malva', 104325),
#  ('Gentiana', 104521),
#  ('Viola', 104649),
#  ('Malva', 10467),
#  ('Ophrys', 104737),
#  ('Geranium', 104873),
#  ('Malva', 104881),
#  ('Ophrys', 104905),
#  ('Crataegus', 105110),
#  ('Geranium', 105166),
#  ('Narcissus', 105458),
#  ('Cirsium', 105701),
#  ('Ophrys', 105718),
#  ('Geranium', 105825),
#  ('Viola', 105869),
#  ('Malva', 106038),
#  ('Campanula', 106147),
#  ('Veronica', 106256),
#  ('Narcissus', 106339),
#  ('Geranium', 106340),
#  ('Ajuga', 10636),
#  ('Geranium', 1064),
#  ('Viola', 106410),
#  ('Campanula', 106433),
#  ('Gentiana', 106558),
#  ('Crataegus', 106663),
#  ('Iris', 106849),
#  ('Cirsium', 106862),
#  ('Allium', 10696),
#  ('Allium', 106980),
#  ('Viola', 107000),
#  ('Campanula', 107114),
#  ('Iris', 10712),
#  ('Crataegus', 107122),
#  ('Verbascum', 107231),
#  ('Iris', 107234),
#  ('Verbascum', 107346),
#  ('Iris', 107382),
#  ('Ophrys', 107411),
#  ('Cirsium', 107471),
#  ('Allium', 107489),
#  ('Ajuga', 107526),
#  ('Geranium', 107530),
#  ('Cirsium', 107584),
#  ('Ophrys', 107659),
#  ('Viola', 107694),
#  ('Rosa', 10777),
#  ('Viola', 107848),
#  ('Trifolium', 107930),
#  ('Viola', 108050),
#  ('Viola', 108130),
#  ('Viola', 108178),
#  ('Geranium', 108308),
#  ('Ophrys', 108310),
#  ('Ophrys', 108321),
#  ('Allium', 108361),
#  ('Narcissus', 108388),
#  ('Viola', 108475),
#  ('Veronica', 108579),
#  ('Veronica', 108589),
#  ('Gentiana', 108641),
#  ('Ophrys', 108759),
#  ('Ophrys', 10880),
#  ('Ophrys', 108874),
#  ('Ajuga', 108996),
#  ('Gentiana', 109016),
#  ('Ophrys', 109026),
#  ('Geranium', 109070),
#  ('Trifolium', 109097),
#  ('Ophrys', 109122),
#  ('Ophrys', 109158),
#  ('Ophrys', 109180),
#  ('Trifolium', 109248),
#  ('Malva', 109352),
#  ('Viola', 109464),
#  ('Ophrys', 109505),
#  ('Geranium', 109527),
#  ('Ophrys', 109581),
#  ('Geranium', 109588),
#  ('Malva', 109932),
#  ('Geranium', 109938),
#  ('Veronica', 110033),
#  ('Malva', 110044),
#  ('Geranium', 110062),
#  ('Ophrys', 11014),
#  ('Ophrys', 110250),
#  ('Campanula', 110521),
#  ('Ophrys', 11056),
#  ('Veronica', 110619),
#  ('Veronica', 110895),
#  ('Campanula', 110905),
#  ('Ophrys', 110983),
#  ('Ophrys', 111268),
#  ('Campanula', 111393),
#  ('Ophrys', 11142),
#  ('Veronica', 111506),
#  ('Trifolium', 111511),
#  ('Campanula', 111822),
#  ('Verbascum', 111927),
#  ('Malva', 111936),
#  ('Geranium', 112030),
#  ('Verbascum', 112038),
#  ('Verbascum', 112094),
#  ('Viola', 112185),
#  ('Ophrys', 112193),
#  ('Campanula', 112205),
#  ('Veronica', 112334),
#  ('Cirsium', 112362),
#  ('Malva', 112443),
#  ('Viola', 112469),
#  ('Gentiana', 112628),
#  ('Crataegus', 11264),
#  ('Ophrys', 11273),
#  ('Ophrys', 11285),
#  ('Gentiana', 112852),
#  ('Ophrys', 112854),
#  ('Veronica', 112973),
#  ('Ophrys', 112982),
#  ('Rosa', 113010),
#  ('Campanula', 113038),
#  ('Rosa', 113117),
#  ('Geranium', 11333),
#  ('Malva', 11386),
#  ('Cirsium', 11427),
#  ('Narcissus', 11471),
#  ('Gentiana', 11529),
#  ('Campanula', 11578),
#  ('Trifolium', 11585),
#  ('Campanula', 11678),
#  ('Crataegus', 1171),
#  ('Geranium', 11719),
#  ('Verbascum', 11792),
#  ('Narcissus', 11879),
#  ('Ophrys', 11990),
#  ('Ophrys', 12044),
#  ('Trifolium', 12059),
#  ('Campanula', 12508),
#  ('Trifolium', 12521),
#  ('Gentiana', 12736),
#  ('Iris', 12744),
#  ('Allium', 12831),
#  ('Narcissus', 12887),
#  ('Iris', 1290),
#  ('Verbascum', 12921),
#  ('Geranium', 12980),
#  ('Ophrys', 13164),
#  ('Campanula', 13333),
#  ('Campanula', 13491),
#  ('Trifolium', 13715),
#  ('Narcissus', 13716),
#  ('Crataegus', 13731),
#  ('Allium', 13869),
#  ('Ophrys', 13876),
#  ('Ophrys', 13908),
#  ('Ophrys', 13944),
#  ('Ophrys', 14147),
#  ('Ophrys', 14192),
#  ('Veronica', 14217),
#  ('Veronica', 1430),
#  ('Allium', 14306),
#  ('Narcissus', 14321),
#  ('Cirsium', 14367),
#  ('Geranium', 14370),
#  ('Cirsium', 14469),
#  ('Veronica', 14481),
#  ('Cirsium', 14714),
#  ('Iris', 14719),
#  ('Verbascum', 14753),
#  ('Iris', 14781),
#  ('Geranium', 14818),
#  ('Campanula', 14847),
#  ('Geranium', 14913),
#  ('Trifolium', 14930),
#  ('Rosa', 15151),
#  ('Malva', 15198),
#  ('Ophrys', 15251),
#  ('Viola', 15341),
#  ('Veronica', 15351),
#  ('Allium', 15445),
#  ('Narcissus', 15461),
#  ('Viola', 15498),
#  ('Allium', 15509),
#  ('Allium', 15544),
#  ('Trifolium', 15708),
#  ('Veronica', 15822),
#  ('Allium', 15859),
#  ('Geranium', 16011),
#  ('Allium', 16068),
#  ('Campanula', 16117),
#  ('Crataegus', 16122),
#  ('Malva', 16370),
#  ('Campanula', 16425),
#  ('Geranium', 16469),
#  ('Trifolium', 16474),
#  ('Allium', 165),
#  ('Cirsium', 16520),
#  ('Veronica', 16631),
#  ('Trifolium', 16794),
#  ('Ophrys', 17065),
#  ('Iris', 17072),
#  ('Iris', 17220),
#  ('Verbascum', 17225),
#  ('Malva', 17248),
#  ('Campanula', 1728),
#  ('Ophrys', 17394),
#  ('Ophrys', 17407),
#  ('Ophrys', 17439),
#  ('Malva', 17510),
#  ('Campanula', 17532),
#  ('Narcissus', 17543),
#  ('Crataegus', 17590),
#  ('Geranium', 17635),
#  ('Iris', 17687),
#  ('Cirsium', 17717),
#  ('Rosa', 17798),
#  ('Ophrys', 1780),
#  ('Iris', 17921),
#  ('Viola', 17958),
#  ('Malva', 17970),
#  ('Ajuga', 18112),
#  ('Geranium', 18200),
#  ('Trifolium', 18272),
#  ('Trifolium', 1835),
#  ('Gentiana', 18574),
#  ('Gentiana', 18641),
#  ('Gentiana', 18646),
#  ('Ophrys', 18772),
#  ('Allium', 18867),
#  ('Rosa', 18944),
#  ('Crataegus', 18959),
#  ('Cirsium', 18992),
#  ('Campanula', 19065),
#  ('Rosa', 19078),
#  ('Ophrys', 19121),
#  ('Trifolium', 1919),
#  ('Veronica', 19270),
#  ('Veronica', 19289),
#  ('Ajuga', 19305),
#  ('Geranium', 19309),
#  ('Viola', 19397),
#  ('Viola', 19593),
#  ('Malva', 19671),
#  ('Ophrys', 19718),
#  ('Narcissus', 19914),
#  ('Allium', 19980),
#  ('Veronica', 20034),
#  ('Geranium', 20042),
#  ('Trifolium', 20077),
#  ('Malva', 20271),
#  ('Malva', 20292),
#  ('Trifolium', 20423),
#  ('Viola', 20466),
#  ('Allium', 20688),
#  ('Geranium', 20710),
#  ('Viola', 20851),
#  ('Malva', 20892),
#  ('Ophrys', 20904),
#  ('Ophrys', 20946),
#  ('Campanula', 20957),
#  ('Iris', 21139),
#  ('Trifolium', 21157),
#  ('Gentiana', 21191),
#  ('Ophrys', 21297),
#  ('Ophrys', 21299),
#  ('Campanula', 21311),
#  ('Ophrys', 21357),
#  ('Ophrys', 21445),
#  ('Verbascum', 21450),
#  ('Viola', 21482),
#  ('Campanula', 21490),
#  ('Ophrys', 21520),
#  ('Iris', 21524),
#  ('Malva', 21581),
#  ('Ophrys', 21595),
#  ('Ophrys', 21756),
#  ('Geranium', 21844),
#  ('Veronica', 21941),
#  ('Campanula', 21956),
#  ('Gentiana', 22024),
#  ('Geranium', 22112),
#  ('Gentiana', 2220),
#  ('Crataegus', 22223),
#  ('Malva', 22373),
#  ('Cirsium', 22419),
#  ('Ophrys', 2249),
#  ('Ophrys', 22595),
#  ('Viola', 22596),
#  ('Malva', 22722),
#  ('Malva', 22735),
#  ('Malva', 22804),
#  ('Trifolium', 22867),
#  ('Campanula', 22973),
#  ('Iris', 23041),
#  ('Gentiana', 23059),
#  ('Veronica', 23183),
#  ('Gentiana', 2321),
#  ('Crataegus', 23225),
#  ('Ophrys', 23228),
#  ('Verbascum', 2326),
#  ('Trifolium', 23514),
#  ('Ophrys', 2371),
#  ('Verbascum', 23734),
#  ('Ophrys', 23778),
#  ('Campanula', 23883),
#  ('Campanula', 23989),
#  ('Campanula', 24020),
#  ('Verbascum', 24031),
#  ('Gentiana', 24128),
#  ('Verbascum', 2432),
#  ('Malva', 24354),
#  ('Crataegus', 24361),
#  ('Veronica', 2439),
#  ('Viola', 24409),
#  ('Viola', 24562),
#  ('Geranium', 24681),
#  ('Ophrys', 24689),
#  ('Iris', 24889),
#  ('Ophrys', 2496),
#  ('Campanula', 25045),
#  ('Cirsium', 25217),
#  ('Ophrys', 25283),
#  ('Trifolium', 25538),
#  ('Verbascum', 25550),
#  ('Malva', 25617),
#  ('Ophrys', 25726),
#  ('Campanula', 25978),
#  ('Geranium', 25979),
#  ('Campanula', 26008),
#  ('Verbascum', 26122),
#  ('Ophrys', 26196),
#  ('Campanula', 26278),
#  ('Ophrys', 26435),
#  ('Viola', 26573),
#  ('Geranium', 26612),
#  ('Narcissus', 26664),
#  ('Malva', 26725),
#  ('Trifolium', 26907),
#  ('Veronica', 27000),
#  ('Ophrys', 27072),
#  ('Gentiana', 27149),
#  ('Malva', 27158),
#  ('Crataegus', 27186),
#  ('Narcissus', 27195),
#  ('Viola', 27376),
#  ('Viola', 27394),
#  ('Geranium', 27404),
#  ('Cirsium', 2742),
#  ('Ophrys', 27608),
#  ('Rosa', 27867),
#  ('Ophrys', 27896),
#  ('Viola', 27961),
#  ('Geranium', 27980),
#  ('Malva', 28136),
#  ('Campanula', 28215),
#  ('Crataegus', 2830),
#  ('Narcissus', 28335),
#  ('Geranium', 28349),
#  ('Crataegus', 2842),
#  ('Ophrys', 28890),
#  ('Ajuga', 28909),
#  ('Campanula', 28927),
#  ('Ophrys', 28934),
#  ('Ophrys', 29116),
#  ('Allium', 29193),
#  ('Viola', 29211),
#  ('Viola', 2935),
#  ('Viola', 29368),
#  ('Viola', 2947),
#  ('Cirsium', 29482),
#  ('Viola', 29513),
#  ('Viola', 29597),
#  ('Geranium', 29606),
#  ('Cirsium', 29700),
#  ('Malva', 29712),
#  ('Gentiana', 29839),
#  ('Ajuga', 29908),
#  ('Allium', 29951),
#  ('Allium', 30018),
#  ('Veronica', 30052),
#  ('Campanula', 30132),
#  ('Gentiana', 30137),
#  ('Gentiana', 30283),
#  ('Geranium', 30479),
#  ('Geranium', 30673),
#  ('Geranium', 30835),
#  ('Narcissus', 30959),
#  ('Ophrys', 31013),
#  ('Cirsium', 31169),
#  ('Verbascum', 3140),
#  ('Veronica', 31496),
#  ('Geranium', 31624),
#  ('Crataegus', 3171),
#  ('Veronica', 31825),
#  ('Gentiana', 31894),
#  ('Gentiana', 31917),
#  ('Narcissus', 31944),
#  ('Trifolium', 31971),
#  ('Gentiana', 32004),
#  ('Ophrys', 32044),
#  ('Ophrys', 32198),
#  ('Gentiana', 32219),
#  ('Viola', 3222),
#  ('Ophrys', 3223),
#  ('Rosa', 3244),
#  ('Ajuga', 32519),
#  ('Iris', 32670),
#  ('Narcissus', 32692),
#  ('Rosa', 3271),
#  ('Campanula', 32754),
#  ('Ophrys', 32788),
#  ('Geranium', 32789),
#  ('Gentiana', 3314),
#  ('Viola', 33143),
#  ('Crataegus', 33198),
#  ('Campanula', 33278),
#  ('Trifolium', 33505),
#  ('Viola', 33759),
#  ('Ophrys', 33852),
#  ('Ophrys', 33859),
#  ('Allium', 34093),
#  ('Ophrys', 34094),
#  ('Ophrys', 34144),
#  ('Allium', 3427),
#  ('Verbascum', 34384),
#  ('Campanula', 345),
#  ('Crataegus', 34634),
#  ('Ophrys', 34664),
#  ('Campanula', 34840),
#  ('Trifolium', 34977),
#  ('Ophrys', 35000),
#  ('Malva', 35245),
#  ('Ophrys', 35251),
#  ('Veronica', 3528),
#  ('Trifolium', 3531),
#  ('Malva', 35379),
#  ('Viola', 35427),
#  ('Trifolium', 35474),
#  ('Allium', 35536),
#  ('Ophrys', 35769),
#  ('Trifolium', 36010),
#  ('Geranium', 36035),
#  ('Ophrys', 36041),
#  ('Cirsium', 36312),
#  ('Crataegus', 36316),
#  ('Veronica', 36334),
#  ('Viola', 36383),
#  ('Viola', 36433),
#  ('Malva', 3654),
#  ('Narcissus', 36651),
#  ('Ajuga', 36679),
#  ('Ophrys', 36711),
#  ('Cirsium', 36721),
#  ('Campanula', 36739),
#  ('Geranium', 3676),
#  ('Geranium', 36862),
#  ('Ophrys', 37152),
#  ('Campanula', 372),
#  ('Geranium', 37345),
#  ('Cirsium', 374),
#  ('Campanula', 37573),
#  ('Geranium', 37739),
#  ('Gentiana', 37867),
#  ('Narcissus', 3797),
#  ('Viola', 38005),
#  ('Veronica', 38012),
#  ('Verbascum', 38073),
#  ('Narcissus', 38297),
#  ('Campanula', 3830),
#  ('Narcissus', 3837),
#  ('Gentiana', 38436),
#  ('Narcissus', 38520),
#  ('Trifolium', 38530),
#  ('Allium', 38665),
#  ('Viola', 3877),
#  ('Ophrys', 38779),
#  ('Allium', 38919),
#  ('Ophrys', 3907),
#  ('Trifolium', 39074),
#  ('Cirsium', 39107),
#  ('Campanula', 39196),
#  ('Cirsium', 39258),
#  ('Veronica', 3934),
#  ('Iris', 39413),
#  ('Iris', 39432),
#  ('Geranium', 39496),
#  ('Verbascum', 39524),
#  ('Malva', 39542),
#  ('Viola', 39551),
#  ('Ophrys', 39674),
#  ('Campanula', 3975),
#  ('Campanula', 39810),
#  ('Ophrys', 39863),
#  ('Ajuga', 39977),
#  ('Ajuga', 40198),
#  ('Iris', 40210),
#  ('Veronica', 4027),
#  ('Ophrys', 40284),
#  ('Rosa', 40288),
#  ('Malva', 4031),
#  ('Ophrys', 40314),
#  ('Narcissus', 40392),
#  ('Viola', 40482),
#  ('Gentiana', 40618),
#  ('Verbascum', 40638),
#  ('Ophrys', 40676),
#  ('Trifolium', 40777),
#  ('Geranium', 40807),
#  ('Geranium', 40810),
#  ('Verbascum', 40847),
#  ('Malva', 40904),
#  ('Trifolium', 40916),
#  ('Cirsium', 41162),
#  ('Ophrys', 41200),
#  ('Geranium', 41281),
#  ('Geranium', 41389),
#  ('Gentiana', 41410),
#  ('Allium', 41452),
#  ('Geranium', 41631),
#  ('Veronica', 41651),
#  ('Ophrys', 41728),
#  ('Veronica', 41782),
#  ('Ajuga', 41972),
#  ('Geranium', 42025),
#  ('Cirsium', 42046),
#  ('Geranium', 42069),
#  ('Malva', 42179),
#  ('Allium', 42346),
#  ('Ophrys', 42357),
#  ('Gentiana', 42443),
#  ('Cirsium', 42526),
#  ('Narcissus', 42642),
#  ('Geranium', 42695),
#  ('Narcissus', 4271),
#  ('Ajuga', 42801),
#  ('Rosa', 42830),
#  ('Iris', 42895),
#  ('Geranium', 42914),
#  ('Trifolium', 43229),
#  ('Gentiana', 43258),
#  ('Gentiana', 43288),
#  ('Campanula', 43332),
#  ('Gentiana', 43370),
#  ('Malva', 43424),
#  ('Campanula', 43447),
#  ('Narcissus', 43501),
#  ('Ajuga', 4360),
#  ('Geranium', 43711),
#  ('Ophrys', 43797),
#  ('Veronica', 43959),
#  ('Trifolium', 44396),
#  ('Campanula', 44451),
#  ('Trifolium', 44552),
#  ('Malva', 44586),
#  ('Trifolium', 4471),
#  ('Veronica', 44775),
#  ('Trifolium', 44797),
#  ('Ajuga', 44967),
#  ('Cirsium', 45),
#  ('Allium', 45058),
#  ('Cirsium', 45295),
#  ('Veronica', 45418),
#  ('Malva', 45692),
#  ('Campanula', 45824),
#  ('Verbascum', 45959),
#  ('Trifolium', 45969),
#  ('Narcissus', 45980),
#  ('Ophrys', 45995),
#  ('Ophrys', 46088),
#  ('Malva', 46093),
#  ('Veronica', 4610),
#  ('Ophrys', 46176),
#  ('Campanula', 46221),
#  ('Narcissus', 46224),
#  ('Campanula', 46233),
#  ('Allium', 46277),
#  ('Ophrys', 46285),
#  ('Ophrys', 46433),
#  ('Malva', 46551),
#  ('Rosa', 46601),
#  ('Ophrys', 46794),
#  ('Gentiana', 46919),
#  ('Geranium', 46921),
#  ('Geranium', 46995),
#  ('Geranium', 47019),
#  ('Geranium', 47043),
#  ('Trifolium', 47120),
#  ('Verbascum', 47248),
#  ('Campanula', 47272),
#  ('Cirsium', 47444),
#  ('Verbascum', 47580),
#  ('Verbascum', 4760),
#  ('Ophrys', 47828),
#  ('Gentiana', 47853),
#  ('Ophrys', 47880),
#  ('Gentiana', 47893),
#  ('Viola', 48006),
#  ('Geranium', 48081),
#  ('Ophrys', 48091),
#  ('Gentiana', 48131),
#  ('Malva', 48192),
#  ('Ophrys', 48267),
#  ('Gentiana', 48389),
#  ('Gentiana', 4840),
#  ('Trifolium', 4860),
#  ('Gentiana', 48620),
#  ('Ophrys', 48727),
#  ('Malva', 48752),
#  ('Gentiana', 48877),
#  ('Geranium', 48884),
#  ('Trifolium', 49023),
#  ('Malva', 4914),
#  ('Malva', 49203),
#  ('Ajuga', 49373),
#  ('Verbascum', 49459),
#  ('Malva', 49563),
#  ('Iris', 49920),
#  ('Veronica', 49925),
#  ('Gentiana', 50133),
#  ('Campanula', 50206),
#  ('Iris', 50297),
#  ('Geranium', 5031),
#  ('Gentiana', 50343),
#  ('Malva', 50345),
#  ('Trifolium', 50530),
#  ('Cirsium', 50543),
#  ('Iris', 50568),
#  ('Geranium', 5084),
#  ('Trifolium', 50867),
#  ('Trifolium', 50962),
#  ('Viola', 51127),
#  ('Crataegus', 51136),
#  ('Viola', 51267),
#  ('Ophrys', 51315),
#  ('Malva', 51417),
#  ('Malva', 51436),
#  ('Campanula', 51502),
#  ('Campanula', 51512),
#  ('Cirsium', 51526),
#  ('Geranium', 51555),
#  ('Ophrys', 5168),
#  ('Geranium', 51779),
#  ('Ajuga', 51789),
#  ('Allium', 51820),
#  ('Rosa', 51890),
#  ('Cirsium', 51913),
#  ('Campanula', 51918),
#  ('Geranium', 51939),
#  ('Ophrys', 52138),
#  ('Ophrys', 52159),
#  ('Narcissus', 52187),
#  ('Ophrys', 52200),
#  ('Campanula', 52272),
#  ('Geranium', 52407),
#  ('Geranium', 52522),
#  ('Geranium', 52621),
#  ('Ophrys', 52673),
#  ('Ophrys', 52682),
#  ('Campanula', 52707),
#  ('Rosa', 52747),
#  ('Iris', 52988),
#  ('Geranium', 53105),
#  ('Narcissus', 53190),
#  ('Geranium', 53195),
#  ('Veronica', 532),
#  ('Veronica', 5322),
#  ('Ophrys', 53277),
#  ('Verbascum', 53331),
#  ('Campanula', 53332),
#  ('Verbascum', 53371),
#  ('Veronica', 53410),
#  ('Cirsium', 53431),
#  ('Verbascum', 53530),
#  ('Ophrys', 53564),
#  ('Cirsium', 53580),
#  ('Verbascum', 53672),
#  ('Allium', 53680),
#  ('Rosa', 53724),
#  ('Verbascum', 54338),
#  ('Allium', 5436),
#  ('Gentiana', 54365),
#  ('Iris', 54394),
#  ('Verbascum', 54444),
#  ('Ophrys', 54587),
#  ('Narcissus', 5474),
#  ('Gentiana', 54789),
#  ('Ophrys', 54843),
#  ('Ophrys', 54858),
#  ('Cirsium', 54898),
#  ('Ophrys', 54962),
#  ('Campanula', 54981),
#  ('Gentiana', 55046),
#  ('Trifolium', 55052),
#  ('Campanula', 5514),
#  ('Malva', 55406),
#  ('Campanula', 55474),
#  ('Iris', 55548),
#  ('Geranium', 55552),
#  ('Veronica', 55704),
#  ('Allium', 55824),
#  ('Geranium', 5585),
#  ('Campanula', 55886),
#  ('Crataegus', 5589),
#  ('Ophrys', 55893),
#  ('Campanula', 55918),
#  ('Cirsium', 55985),
#  ('Narcissus', 55988),
#  ('Narcissus', 56033),
#  ('Geranium', 56074),
#  ('Narcissus', 56081),
#  ('Geranium', 56364),
#  ('Campanula', 5643),
#  ('Ophrys', 56527),
#  ('Ophrys', 56575),
#  ('Ophrys', 56637),
#  ('Geranium', 56649),
#  ('Iris', 56736),
#  ('Geranium', 56809),
#  ('Iris', 56920),
#  ('Malva', 5696),
#  ('Malva', 57031),
#  ('Viola', 57099),
#  ('Malva', 57147),
#  ('Ophrys', 57163),
#  ('Gentiana', 57168),
#  ('Ophrys', 57333),
#  ('Gentiana', 57347),
#  ('Trifolium', 5738),
#  ('Campanula', 57408),
#  ('Geranium', 57538),
#  ('Geranium', 57631),
#  ('Malva', 57773),
#  ('Ophrys', 57898),
#  ('Verbascum', 57959),
#  ('Geranium', 57995),
#  ('Ophrys', 58140),
#  ('Cirsium', 58174),
#  ('Ophrys', 5828),
#  ('Verbascum', 58300),
#  ('Geranium', 58325),
#  ('Verbascum', 5852),
#  ('Ophrys', 58578),
#  ('Geranium', 58616),
#  ('Geranium', 58617),
#  ('Ophrys', 58660),
#  ('Ophrys', 58710),
#  ('Malva', 58808),
#  ('Malva', 58862),
#  ('Ajuga', 5900),
#  ('Ajuga', 59229),
#  ('Ophrys', 59299),
#  ('Malva', 59397),
#  ('Crataegus', 59412),
#  ('Ajuga', 59509),
#  ('Narcissus', 59581),
#  ('Ophrys', 59614),
#  ('Cirsium', 59629),
#  ('Rosa', 59730),
#  ('Geranium', 59798),
#  ('Allium', 59809),
#  ('Gentiana', 59881),
#  ('Viola', 59895),
#  ('Viola', 60040),
#  ('Campanula', 60228),
#  ('Ophrys', 60312),
#  ('Allium', 60433),
#  ('Geranium', 60501),
#  ('Iris', 60508),
#  ('Ophrys', 60527),
#  ('Campanula', 60618),
#  ('Viola', 60641),
#  ('Geranium', 60692),
#  ('Allium', 60807),
#  ('Viola', 60853),
#  ('Viola', 60918),
#  ('Ophrys', 60994),
#  ('Malva', 61002),
#  ('Iris', 61019),
#  ('Campanula', 61061),
#  ('Viola', 61071),
#  ('Verbascum', 61188),
#  ('Ophrys', 61248),
#  ('Verbascum', 61262),
#  ('Geranium', 61308),
#  ('Campanula', 61482),
#  ('Geranium', 61544),
#  ('Ophrys', 61551),
#  ('Geranium', 61649),
#  ('Campanula', 61896),
#  ('Trifolium', 62),
#  ('Ophrys', 620),
#  ('Gentiana', 62066),
#  ('Rosa', 62103),
#  ('Campanula', 62227),
#  ('Viola', 62331),
#  ('Malva', 62337),
#  ('Ophrys', 62479),
#  ('Viola', 62539),
#  ('Ophrys', 62650),
#  ('Campanula', 62684),
#  ('Geranium', 62809),
#  ('Veronica', 62970),
#  ('Malva', 63126),
#  ('Campanula', 63149),
#  ('Gentiana', 63198),
#  ('Ophrys', 63385),
#  ('Geranium', 63392),
#  ('Iris', 63420),
#  ('Viola', 63484),
#  ('Allium', 63584),
#  ('Malva', 63675),
#  ('Viola', 63687),
#  ('Campanula', 63697),
#  ('Allium', 63766),
#  ('Campanula', 63779),
#  ('Geranium', 6392),
#  ('Campanula', 63961),
#  ('Narcissus', 63988),
#  ('Viola', 64095),
#  ('Gentiana', 64263),
#  ('Geranium', 64310),
#  ('Gentiana', 64523),
#  ('Campanula', 64597),
#  ('Verbascum', 64648),
#  ('Allium', 64805),
#  ('Verbascum', 64875),
#  ('Iris', 64883),
#  ('Verbascum', 64985),
#  ('Iris', 65041),
#  ('Trifolium', 6516),
#  ('Ophrys', 6522),
#  ('Ophrys', 65230),
#  ('Narcissus', 65364),
#  ('Veronica', 65470),
#  ('Geranium', 65549),
#  ('Gentiana', 65671),
#  ('Ophrys', 65746),
#  ('Allium', 65831),
#  ('Ophrys', 65974),
#  ('Ophrys', 66088),
#  ('Campanula', 66121),
#  ('Verbascum', 66123),
#  ('Malva', 66302),
#  ('Cirsium', 66430),
#  ('Geranium', 66494),
#  ('Narcissus', 6650),
#  ('Allium', 66538),
#  ('Allium', 66551),
#  ('Allium', 66577),
#  ('Trifolium', 66617),
#  ('Veronica', 66692),
#  ('Veronica', 66750),
#  ('Veronica', 66752),
#  ('Geranium', 66958),
#  ('Campanula', 6697),
#  ('Geranium', 67109),
#  ('Narcissus', 67182),
#  ('Malva', 67245),
#  ('Malva', 67407),
#  ('Allium', 6743),
#  ('Ophrys', 67498),
#  ('Malva', 67572),
#  ('Gentiana', 67675),
#  ('Campanula', 67810),
#  ('Ophrys', 67888),
#  ('Gentiana', 68107),
#  ('Malva', 68123),
#  ('Ajuga', 68128),
#  ('Viola', 68164),
#  ('Ophrys', 68313),
#  ('Ophrys', 68325),
#  ('Malva', 68375),
#  ('Malva', 68481),
#  ('Campanula', 68612),
#  ('Campanula', 68712),
#  ('Rosa', 68742),
#  ('Ophrys', 68756),
#  ('Verbascum', 68788),
#  ('Verbascum', 68884),
#  ('Trifolium', 69016),
#  ('Allium', 69261),
#  ('Campanula', 69285),
#  ('Campanula', 6930),
#  ('Malva', 69327),
#  ('Veronica', 69359),
#  ('Viola', 69451),
#  ('Allium', 69555),
#  ('Ophrys', 69625),
#  ('Malva', 69705),
#  ('Ophrys', 69804),
#  ('Campanula', 69904),
#  ('Viola', 69923),
#  ('Ajuga', 69998),
#  ('Rosa', 7001),
#  ('Ophrys', 70072),
#  ('Ophrys', 70100),
#  ('Ophrys', 70334),
#  ('Cirsium', 70386),
#  ('Narcissus', 70647),
#  ('Ophrys', 70651),
#  ('Viola', 70673),
#  ('Cirsium', 70713),
#  ('Viola', 70776),
#  ('Ophrys', 71109),
#  ('Ajuga', 71182),
#  ('Malva', 71231),
#  ('Geranium', 71315),
#  ('Cirsium', 71380),
#  ('Allium', 71545),
#  ('Ophrys', 71580),
#  ('Campanula', 71611),
#  ('Verbascum', 71652),
#  ('Geranium', 71692),
#  ('Viola', 71701),
#  ('Verbascum', 71768),
#  ('Geranium', 71855),
#  ('Viola', 7189),
#  ('Allium', 71907),
#  ('Ophrys', 71979),
#  ('Malva', 72007),
#  ('Ophrys', 72185),
#  ('Ajuga', 72232),
#  ('Ophrys', 72332),
#  ('Ophrys', 72383),
#  ('Campanula', 7240),
#  ('Verbascum', 72432),
#  ('Veronica', 7247),
#  ('Ophrys', 725),
#  ('Trifolium', 72524),
#  ('Verbascum', 7265),
#  ('Cirsium', 72750),
#  ('Ophrys', 72798),
#  ('Geranium', 7295),
#  ('Allium', 73101),
#  ('Malva', 73212),
#  ('Malva', 7342),
#  ('Campanula', 73423),
#  ('Ophrys', 73461),
#  ('Geranium', 73508),
#  ('Gentiana', 73663),
#  ('Malva', 73824),
#  ('Viola', 7383),
#  ('Gentiana', 73842),
#  ('Viola', 73875),
#  ('Gentiana', 73905),
#  ...]

# %%
y_true = np.stack(y_list, axis = 0)

# %%
y_pred_df['pred_genus'] = y_pred_df.idxmax(axis = 1)
y_pred_df['pred_genus']
# Out:
# 0          Ophrys
# 1            Iris
# 2        Geranium
# 3        Gentiana
# 4       Campanula
# 5          Ophrys
# 6          Ophrys
# 7        Gentiana
# 8          Ophrys
# 9        Geranium
# 10       Geranium
# 11       Geranium
# 12       Geranium
# 13       Geranium
# 14         Ophrys
# 15         Ophrys
# 16       Geranium
# 17       Gentiana
# 18         Ophrys
# 19           Iris
# 20       Geranium
# 21         Ophrys
# 22       Gentiana
# 23         Allium
# 24          Ajuga
# 25         Ophrys
# 26         Ophrys
# 27         Ophrys
# 28      Narcissus
# 29       Gentiana
#           ...
# 1311     Gentiana
# 1312       Ophrys
# 1313     Gentiana
# 1314     Gentiana
# 1315       Ophrys
# 1316     Geranium
# 1317     Veronica
# 1318       Ophrys
# 1319     Geranium
# 1320     Gentiana
# 1321     Geranium
# 1322     Gentiana
# 1323       Ophrys
# 1324       Ophrys
# 1325     Geranium
# 1326     Gentiana
# 1327     Geranium
# 1328       Ophrys
# 1329     Gentiana
# 1330     Gentiana
# 1331         Iris
# 1332       Ophrys
# 1333       Ophrys
# 1334       Ophrys
# 1335       Ophrys
# 1336       Ophrys
# 1337     Gentiana
# 1338      Cirsium
# 1339     Geranium
# 1340       Ophrys
# Name: pred_genus, Length: 1341, dtype: object

# %%
prediction_review = (y_pred_df['pred_genus'] == y_true_df['true_genus'])

# %%
prediction_review.count()
# Out:
# 1341

# %%
prediction_vec_df = y_pred_df[['pred_genus']].copy()
prediction_vec_df['true_genus'] = y_true_df['true_genus'].copy()
prediction_vec_df['result'] = (y_pred_df['pred_genus'] == y_true_df['true_genus'])

# %%
prediction_vec_df['false'] = prediction_vec_df['result'].apply(lambda x: 1 if x == False else 0)
prediction_vec_df['true'] = prediction_vec_df['result'].apply(lambda x: 1 if x == True else 0)
prediction_vec_df.head(2)
# Out:
#   pred_genus true_genus  result  false  true
# 0     Ophrys  Verbascum   False      1     0
# 1       Iris  Trifolium   False      1     0

# %%
true_pos_neg = prediction_vec_df.groupby('true_genus').sum().drop(columns=['result'])
true_pos_neg['percent_true'] = true_pos_neg['true'] / (true_pos_neg['true'] + true_pos_neg['false'])

# %%
success_ratio = round(true_pos_neg[['percent_true']]*100).sort_values(by='percent_true', ascending=False)

# %%
success_ratio
# Out:
#             percent_true
# true_genus
# Ophrys              82.0
# Gentiana            76.0
# Geranium            60.0
# Narcissus           47.0
# Verbascum           21.0
# Campanula           16.0
# Iris                 6.0
# Veronica             2.0
# Cirsium              1.0
# Ajuga                0.0
# Allium               0.0
# Crataegus            0.0
# Malva                0.0
# Rosa                 0.0
# Trifolium            0.0
# Viola                0.0

# %% [markdown]
# ##### genus success by number of images in dataset

# %%
train_df = pd.read_csv('../plantbase/data/priority_plants_VF.csv').drop(columns = 'Unnamed: 0')

# %%
success_ratio['sample_size'] = train_df.groupby('genus').count()['content']

# %%
success_ratio = success_ratio.drop(columns='Sample Size')
success_ratio
# Out:
#             percent_true  sample_size
# true_genus
# Ophrys              82.0          660
# Gentiana            76.0          296
# Geranium            60.0          436
# Narcissus           47.0          223
# Verbascum           21.0          295
# Campanula           16.0          381
# Iris                 6.0          154
# Veronica             2.0          200
# Cirsium              1.0          231
# Ajuga                0.0          119
# Allium               0.0          232
# Crataegus            0.0          183
# Malva                0.0          289
# Rosa                 0.0          150
# Trifolium            0.0          214
# Viola                0.0          254

# %%
plt.scatter(success_ratio['percent_true'], success_ratio['sample_size'])

# %%
sns.scatterplot(x = success_ratio['sample_size'], y = success_ratio['percent_true'])
# Out:
# <AxesSubplot:xlabel='sample_size', ylabel='percent_true'>

# %% [markdown]
# #### testing overall accuracy

# %%
y_true.shape
# Out:
# (1341, 2)

# %%
X_test.shape
# Out:
# (1341, 256, 256, 3)

# %%
y_preds = model.predict(X_test)

# %%
y_preds.shape
# Out:
# (1341, 16)

# %%
y_preds[0]
# Out:
# array([-0.37504542, -1.0996858 , -0.7115953 ,  0.47309953, -1.1717073 ,
#         1.0166441 ,  0.12285591,  0.48726088, -0.6126306 ,  0.4526932 ,
#         1.6858617 , -1.3366513 , -0.01122154,  1.4891592 , -2.9787095 ,
#        -1.3380568 ], dtype=float32)

# %%
y_pred_df = pd.DataFrame(y_preds)
y_pred_df = y_pred_df.rename(columns=rename_columns)

y_pred_df.head()
# Out:
#       Ajuga    Allium  Campanula   Cirsium  Crataegus  Gentiana  Geranium  \
# 0 -0.375045 -1.099686  -0.711595  0.473100  -1.171707  1.016644  0.122856
# 1  1.976996 -2.604533   0.189381 -2.215130  -2.773472  2.029676  0.528427
# 2  0.150083 -0.651813   0.673039  0.582385  -0.504183  0.727306  1.392239
# 3  0.416089 -0.901790   1.403908  0.517593  -0.540563  2.253790  0.440279
# 4  0.356223 -0.765871   1.017924  0.210691  -0.437511  0.784489  1.003653
#
#        Iris     Malva  Narcissus    Ophrys      Rosa  Trifolium  Verbascum  \
# 0  0.487261 -0.612631   0.452693  1.685862 -1.336651  -0.011222   1.489159
# 1  2.589401 -0.221971   0.905883 -1.673178 -1.438025  -2.276607  -0.319322
# 2 -0.345021 -0.074036  -1.064208  0.925776 -0.683254  -0.934431  -0.952826
# 3  0.955896  0.439329   0.088416  0.306997 -1.375822  -1.279450  -1.936976
# 4 -0.186409  0.282302  -1.088736  0.162990 -0.803298  -1.426403  -1.422720
#
#    Veronica     Viola
# 0 -2.978709 -1.338057
# 1  1.084313  1.045270
# 2  0.104517 -0.144562
# 3 -0.425926  0.387330
# 4  0.726319  0.201529

# %%
y_true[:,0]
# Out:
# array(['Verbascum', 'Trifolium', 'Veronica', ..., 'Campanula',
#        'Campanula', 'Cirsium'], dtype='<U9')

# %%
y_pred_df.shape, y_true[:,0].shape
# Out:
# ((1341, 16), (1341,))

# %%
y_pred_df['pred_genus'] = y_pred_df.idxmax(axis=1)
y_pred_df['true_genus'] = y_true[:,0]

# %%
y_pred_df.head()
# Out:
#       Ajuga    Allium  Campanula   Cirsium  Crataegus  Gentiana  Geranium  \
# 0 -0.375045 -1.099686  -0.711595  0.473100  -1.171707  1.016644  0.122856
# 1  1.976996 -2.604533   0.189381 -2.215130  -2.773472  2.029676  0.528427
# 2  0.150083 -0.651813   0.673039  0.582385  -0.504183  0.727306  1.392239
# 3  0.416089 -0.901790   1.403908  0.517593  -0.540563  2.253790  0.440279
# 4  0.356223 -0.765871   1.017924  0.210691  -0.437511  0.784489  1.003653
#
#        Iris     Malva  Narcissus    Ophrys      Rosa  Trifolium  Verbascum  \
# 0  0.487261 -0.612631   0.452693  1.685862 -1.336651  -0.011222   1.489159
# 1  2.589401 -0.221971   0.905883 -1.673178 -1.438025  -2.276607  -0.319322
# 2 -0.345021 -0.074036  -1.064208  0.925776 -0.683254  -0.934431  -0.952826
# 3  0.955896  0.439329   0.088416  0.306997 -1.375822  -1.279450  -1.936976
# 4 -0.186409  0.282302  -1.088736  0.162990 -0.803298  -1.426403  -1.422720
#
#    Veronica     Viola pred_genus true_genus
# 0 -2.978709 -1.338057     Ophrys  Verbascum
# 1  1.084313  1.045270       Iris  Trifolium
# 2  0.104517 -0.144562   Geranium   Veronica
# 3 -0.425926  0.387330   Gentiana  Campanula
# 4  0.726319  0.201529  Campanula   Geranium

# %%
prediction_review = (y_pred_df['pred_genus'] == y_pred_df['true_genus'])
accuracy = prediction_review.value_counts()[True] / prediction_review.count()
print(f'test accuracy: {accuracy}')
# Out:
# test accuracy: 0.30275913497390006

# %%
y_true
# Out:
# array([['Verbascum', '100035'],
#        ['Trifolium', '100058'],
#        ['Veronica', '100186'],
#        ...,
#        ['Campanula', '99914'],
#        ['Campanula', '99963'],
#        ['Cirsium', '9997']], dtype='<U9')

# %%
 # get predictions for all species
y_pred = model.predict(self.X_test)
columns = self.label_enc.classes_
y_pred_df = pd.DataFrame(y_pred, columns=columns)

# get species with top prediction and true species
y_pred_df['pred_genus'] = y_pred_df.idxmax(axis=1)
y_pred_df['true_genus'] = self.y_test

# measure success rate
prediction_review = (y_pred_df['pred_genus'] == y_pred_df['true_genus'])
accuracy = prediction_review.value_counts()[True] / prediction_review.count()
print(f'test accuracy: {accuracy}')
# Out:
#   File "<ipython-input-48-ec697ced28db>", line 2
#     y_pred = model.predict(self.X_test)
#     ^
# IndentationError: unexpected indent
